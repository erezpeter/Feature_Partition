# %%
import numpy as np
import scipy
import scipy.spatial
from scipy.spatial.distance import squareform,pdist,cdist
import matplotlib.pyplot as plt
from scipy.io import mmread

from sklearn.manifold import TSNE
from joblib import Parallel, delayed

from timeit import default_timer as timer

# %%
import sys
import os

# Add the parent directory to sys.path
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# # Experiment

# %% [markdown]
# ### load data

# %%
# x_all : Count matrix data from batch A (cells × genes)
# layers : Liver layer annotations for each sample
# time : Circadian clock time annotations for each sample

# %%
print(x_all.shape)
print(len(layers))
# Out:
# (6889, 14812)
# 6889

# %% [markdown]
# ### Preprocess data

# %%
import scanpy as sc
adata = sc.AnnData(x_all.tocsr())

sc.pp.filter_cells(adata, min_genes=100)
sc.pp.filter_genes(adata, min_cells=3)

sc.pp.normalize_total(adata,target_sum=1e6)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata,n_top_genes=2000)
sc.pp.scale(adata)

data = adata.X[:,np.where(adata.var['highly_variable'])[0]]

# %%
x_all.shape
# Out:
# (6889, 14812)

# %%
data.shape
# Out:
# (6889, 2000)

# %% [markdown]
# # Choose SVD/PCA dim

# %%
from FP import *
x_SVD= SVD_mean_shifted(data,500)
x= (x[0][:,:20])* (x[1][None,:20])

# %%
f,ax= plt.subplots(1,2)
ax[0].plot(x_SVD[1])
ax[1].plot(x_SVD[1][:50])

# %% [markdown]
# # FP

# %%
x.shape
# Out:
# (6889, 20)

# %%
K=2
perplexity=40

FP_K2 = FP(K=K, perplexity=perplexity)

FP_K2.fit(x, verbose_updates= True,  simulations=100)
# Out:
# Begin sim 0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 14 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 11 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   15
# Current delta = 0.17655678511028236  amount 1/2 2 amount 01   16
# Current delta = 0.17655678511028236  amount 1/2 1 amount 01   18
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# 0 : 0 : 29.479928544304126
# sim time   353.82216143608093
# Begin sim 1
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   18
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088213 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 14 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   18
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088213 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   435.73910880088806
# Begin sim 16
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.554922457040988 :: 28.554922457041926
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   355.9934780597687
# Begin sim 17
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 13 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   18
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088963 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   378.06912636756897
# Begin sim 18
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 39.16154235018103 :: 39.1615435074517
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 13 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088213 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   373.08552050590515
# Begin sim 19
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   358.20306038856506
# Begin sim 20
# Current delta = 2.8249085617645178  amount 1/2 18 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 13 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.554922457040988 :: 28.554922457041926
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   363.5019073486328
# Begin sim 21
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 13 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.411870374944137 :: 28.41187037495409
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   335.6374204158783
# Begin sim 22
# Current delta = 2.8249085617645178  amount 1/2 19 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.17655678511028236  amount 1/2 2 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 1 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 1 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 1 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.51139582646251 :: 29.511395826462554
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   379.2736728191376
# Begin sim 52
# Current delta = 2.8249085617645178  amount 1/2 19 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 11 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   18
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088963 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   378.9874346256256
# Begin sim 53
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.3021450455284 :: 28.302145045531244
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# 53 : 0 : 27.99619545101145
# sim time   274.87041902542114
# Begin sim 54
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   339.4270851612091
# Begin sim 55
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088213 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   346.5825791358948
# Begin sim 56
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 13 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088213 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   332.96871757507324
# Begin sim 57
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.17655678511028236  amount 1/2 19 amount 01   0
# Current delta = 0.17655678511028236  amount 1/2 17 amount 01   2
# Current delta = 0.17655678511028236  amount 1/2 12 amount 01   4
# Current delta = 0.17655678511028236  amount 1/2 3 amount 01   13
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   18
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.661082680079033 :: 28.6610827021573
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.35513310763759 :: 28.355133107659906
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   238.55563473701477
# Begin sim 58
# Current delta = 2.8249085617645178  amount 1/2 19 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   7
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088963 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   330.29843163490295
# Begin sim 59
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 19 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 11 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.54722264326351 :: 29.54722264327099
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   303.15740633010864
# Begin sim 60
# Current delta = 2.8249085617645178  amount 1/2 18 amount 01   1
# Current delta = 2.8249085617645178  amount 1/2 19 amount 01   1
# Current delta = 2.8249085617645178  amount 1/2 19 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.554922457040988 :: 28.554922457041926
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   343.5044014453888
# Begin sim 61
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 10 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.554922457040988 :: 28.554922457041926
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   310.51552724838257
# Begin sim 62
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 11 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.62153263147321 :: 28.621532947144072
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.31558335262431 :: 28.315583352625183
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   319.332457780838
# Begin sim 63
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   3
# Current delta = 0.3531135702205647  amount 1/2 13 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 11 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 5 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   333.6090416908264
# Begin sim 64
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 15 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 12 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   8
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   12
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   17
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.856015088088963 :: 29.856015725902438
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 29.5500661313827 :: 29.55006613138375
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   330.44003677368164
# Begin sim 65
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 9 amount 01   5
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   17
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.68982901164221 :: 28.689829011644946
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   297.70242285728455
# Begin sim 66
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.17655678511028236  amount 1/2 19 amount 01   0
# Current delta = 0.17655678511028236  amount 1/2 16 amount 01   2
# Current delta = 0.17655678511028236  amount 1/2 7 amount 01   9
# Current delta = 0.17655678511028236  amount 1/2 5 amount 01   12
# Current delta = 0.17655678511028236  amount 1/2 1 amount 01   16
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   18
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   250.0177628993988
# Begin sim 67
# Current delta = 2.8249085617645178  amount 1/2 19 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 17 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 11 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 8 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   10
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   13
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   15
# Current delta = 0.3531135702205647  amount 1/2 2 amount 01   16
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   18
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 1 amount 01   19
# Current delta = 0.3531135702205647  amount 1/2 0 amount 01   19
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.17655678511028236  amount 1/2 0 amount 01   20
# Current delta = 0.08827839255514118  amount 1/2 0 amount 01   20
# Current delta = 0.04413919627757059  amount 1/2 0 amount 01   20
# Current delta = 0.022069598138785295  amount 1/2 0 amount 01   20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# old val is higher than cur val 28.68982901164221 :: 28.689829011644946
# Current delta = 0.011034799069392648  amount 1/2 0 amount 01   20
# Current delta = 0.005517399534696324  amount 1/2 0 amount 01   20
# Current delta = 0.0  amount 1/2 0 amount 01   20
# sim time   338.2999093532562
# Begin sim 68
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 2.8249085617645178  amount 1/2 20 amount 01   0
# Current delta = 1.4124542808822589  amount 1/2 20 amount 01   0
# Current delta = 0.7062271404411294  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 20 amount 01   0
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   1
# Current delta = 0.3531135702205647  amount 1/2 18 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   2
# Current delta = 0.3531135702205647  amount 1/2 16 amount 01   4
# Current delta = 0.3531135702205647  amount 1/2 11 amount 01   6
# Current delta = 0.3531135702205647  amount 1/2 7 amount 01   9
# Current delta = 0.3531135702205647  amount 1/2 6 amount 01   11
# Current delta = 0.3531135702205647  amount 1/2 4 amount 01   14
# Current delta = 0.3531135702205647  amount 1/2 3 amount 01   14

# %%
print(FP_K2.get_optimization_summary()['simulation_id'])
# Out:
# 53

# %%
print(FP_K2.get_optimization_summary()['objective_value'])
# Out:
# np.float64(27.99619545101145)

# %% [markdown]
# ### Visualizations

# %%
feat_partitions = FP_K2.get_feature_partitions()

# %%
from sklearn.manifold import TSNE

emb_all = TSNE(n_components=2, random_state=42,perplexity=40).fit_transform( x)

emb_ours=[]
for i in range(K):
    tsne = TSNE(n_components=2, random_state=42,perplexity=40)
    emb_FP.append( tsne.fit_transform( x[:, feat_partitions[i]])   )

# %%
f,ax= plt.subplots(1,3,figsize=(7,3.5))

for i,lab in enumerate(np.unique(times)):
    label= str(['ZT0', 'ZT6','ZT12', 'ZT18'][i])
    inds= np.where(times==lab)[0]
    ax[0].scatter(emb_all[inds,0],emb_all[inds,1],alpha=0.5,label= label,s=1)
    
    ax[1].scatter(emb_FP[0][inds,0],emb_FP[0][inds,1],alpha=0.5,label= lab,s=1)

    ax[2].scatter(emb_FP[1][inds,0],emb_FP[1][inds,1],alpha=0.5,label= lab,s=1)

leg = f.legend(handles= ax[0].get_legend_handles_labels()[0],loc="center left", bbox_to_anchor=(.93, 0.5), fontsize=12, labelspacing=1.5)
for handle in leg.legend_handles:
    handle.set_sizes([50.0])

ax[0].set_title('All Features ',fontsize=16)
ax[1].set_title('tSNE Embedding Based on \n Partition 1',fontsize=16)
ax[2].set_title('Partition 2',fontsize=16)
for cur_ax in ax.flatten():
    cur_ax.axis('square')#,adjustable='box')

for cur_ax in ax.flatten():
    ymin,ymax= cur_ax.get_ylim()
    cur_ax.set_ylim([0-(ymax-ymin)/2,(ymax-ymin)/2])

for i in range(1,3):  # 3 rows
    ax[i].tick_params(left=False, labelleft=False)


plt.suptitle('Cells Colored by Circadian Clock Phase', fontsize=18,y=1.04)

# %%
f,ax= plt.subplots(3,len((np.unique(layers))),figsize=(10,7))

for i,lab in enumerate(np.unique(layers)):
    inds= np.where(layers==lab)[0]

    ax[0,i].scatter(emb_all[:,0],emb_all[:,1],alpha=1,s=1)
    ax[0,i].scatter(emb_all[inds,0],emb_all[inds,1],alpha=1,label= label,s=1)
    
    ax[1,i].scatter(-emb_FP[0][:,0],emb_FP[0][:,1],alpha=1,label= lab,s=1)
    ax[1,i].scatter(-emb_FP[0][inds,0],emb_FP[0][inds,1],alpha=1,label= lab,s=1)

    ax[2,i].scatter(emb_FP[1][:,0],emb_FP[1][:,1],alpha=1,label= lab,s=1)
    ax[2,i].scatter(emb_FP[1][inds,0],emb_FP[1][inds,1],alpha=1,label= lab,s=1)

    if i!=3:
        ax[0,i].set_title('Layer '+str(lab)+'\n',fontsize=16)
    else:
        ax[0,i].set_title('Layer '+str(lab)+'\n tSNE Embedding',fontsize=16)

ax[1,3].set_title('tSNE Embedding based on Partition 1',fontsize=16)
ax[2,3].set_title('tSNE Embedding based on Partition 2',fontsize=16)

plt.suptitle("Cells Displayed Across Layers: \n All Cells in Blue, Specific Layer Overlaid in Orange",fontsize=20)
plt.tight_layout()
for cur_ax in ax.flatten():
    cur_ax.axis('square')#,adjustable='box')

for i in range(1,3):
    for j in range(len(np.unique(layers))):
        ymin,ymax= ax[i,j].get_ylim()

        ax[i,j].set_ylim([0-(ymax-ymin)/2,(ymax-ymin)/2])
    
for i in range(3):  # 3 rows
    for j in range(1,len((np.unique(layers)))):
        ax[i, j].tick_params(left=False, labelleft=False)


plt.subplots_adjust(wspace=0., hspace=.01)
