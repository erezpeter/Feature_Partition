# %%
import numpy as np
import scipy
import scipy.spatial
from scipy.spatial.distance import squareform,pdist,cdist
import matplotlib.pyplot as plt
from scipy.io import mmread

from sklearn.manifold import TSNE
from joblib import Parallel, delayed

from timeit import default_timer as timer

import scanpy as sc
import anndata as ad


from scipy.sparse import csr_matrix
import pandas as pd
import anndata as ad

# %%
import sys
import os

# Add the parent directory to sys.path
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# # Experimnet

# %% [markdown]
# ### Load data

# %%
# df_meta : E14_5 WLS CTL meta data
# df : E14_5 WLS CTL raw data

# %%
cell_types= np.array(df_meta['celltype'].values)
phase_types= np.array(df_meta['Phase'].values)

# %%
print(np.unique(cell_types))
print(np.unique(phase_types))
# Out:
# ['DC' 'LD' 'UD']
# ['G1' 'G2M' 'S']

# %%
x_orig= df.values.T[1:]
gene_names_orig=  df.values.T[0]

# %% [markdown]
# # Preprocess data

# %%
x_adata = ad.AnnData(x_orig+0.)

sc.pp.filter_cells(x_adata, min_genes=10)
sc.pp.filter_genes(x_adata, min_cells=3)

sc.pp.normalize_total(x_adata,target_sum=1e6)
sc.pp.log1p(x_adata)
sc.pp.highly_variable_genes(x_adata,n_top_genes=10000)
sc.pp.scale(x_adata)

# %%
x = x_adata.X[:,np.where(x_adata.var['highly_variable'])[0]]+0.
gene_names = gene_names_orig[x_adata.var['highly_variable'].index.to_numpy()[np.where(x_adata.var['highly_variable'])].astype(int)]

x.shape
# Out:
# (5572, 10000)

# %%
from collections import Counter
print(Counter(cell_types))
print(Counter(phase_types))
# Out:
# Counter({'UD': 3576, 'LD': 1793, 'DC': 203})
# Counter({'G1': 2785, 'G2M': 1420, 'S': 1367})

# %%
for ct in np.unique(cell_types):
    for pt in np.unique(phase_types):
        
        print( pt+'  percentage within '+ct+'  :'+str( np.round(len(np.where( (cell_types==ct)*(phase_types==pt))[0])/ len(np.where( cell_types==ct)[0]),2)))
# Out:
# G1  percentage within DC  :0.97
# G2M  percentage within DC  :0.01
# S  percentage within DC  :0.02
# G1  percentage within LD  :0.69
# G2M  percentage within LD  :0.14
# S  percentage within LD  :0.17
# G1  percentage within UD  :0.38
# G2M  percentage within UD  :0.33
# S  percentage within UD  :0.3

# %% [markdown]
# ## Choose rank

# %%
from FP import *

# %%
x_SVD = SVD_mean_shifted( x,500)
x_new_SVD= (x_SVD[0][::,:50], x_SVD[1][:50], x_SVD[2][:50,:])

# %%
f,ax= plt.subplots(1,2)
ax[0].plot(x_SVD[1])
ax[1].plot(x_SVD[1][:30])

# %% [markdown]
# # run algorithm

# %%
K=2
perplexity=40

verbose_updates= True


FP_K2 = FP(K=K, perplexity=perplexity)

# %%
FP_K2.fit(x_new_SVD, verbose_updates= verbose_updates, simulations=100)
# Out:
# Begin sim 0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 10000 amount 01   0
# Current delta = 0.015678118493940248  amount 1/2 9989 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9988 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9966 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9835 amount 01   41
# Current delta = 0.015678118493940248  amount 1/2 9664 amount 01   184
# Current delta = 0.015678118493940248  amount 1/2 9416 amount 01   313
# Current delta = 0.015678118493940248  amount 1/2 9185 amount 01   427
# Current delta = 0.015678118493940248  amount 1/2 9049 amount 01   521
# Current delta = 0.015678118493940248  amount 1/2 8954 amount 01   576
# Current delta = 0.015678118493940248  amount 1/2 8886 amount 01   605
# Current delta = 0.007839059246970124  amount 1/2 8010 amount 01   1167
# Current delta = 0.007839059246970124  amount 1/2 7575 amount 01   1526
# Current delta = 0.007839059246970124  amount 1/2 7331 amount 01   1710
# Current delta = 0.007839059246970124  amount 1/2 
amount 01   3192
# Current delta = 0.003919529623485062  amount 1/2 5406 amount 01   3285
# Current delta = 0.001959764811742531  amount 1/2 3921 amount 01   4647
# Current delta = 0.001959764811742531  amount 1/2 3678 amount 01   4859
# Current delta = 0.0009798824058712655  amount 1/2 2089 amount 01   6404
# Current delta = 0.0009798824058712655  amount 1/2 1935 amount 01   6588
# Current delta = 0.0004899412029356327  amount 1/2 1009 amount 01   8098
# Current delta = 0.00024497060146781637  amount 1/2 430 amount 01   9097
# Current delta = 0.00012248530073390818  amount 1/2 218 amount 01   9577
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   495.0279026031494
# Begin sim 48
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 10000 amount 01   0
# Current delta = 0.015678118493940248  amount 1/2 9989 amount 01   9
# Current delta = 0.015678118493940248  amount 1/2 9987 amount 01   11
# Current delta = 0.007839059246970124  amount 1/2 9826 amount 01   34
# Current delta = 0.007839059246970124  amount 1/2 9505 amount 01   314
# Current delta = 0.007839059246970124  amount 1/2 8739 amount 01   691
# Current delta = 0.007839059246970124  amount 1/2 8091 amount 01   1119
# Current delta = 0.007839059246970124  amount 1/2 7727 amount 01   1425
# Current delta = 0.007839059246970124  amount 1/2 7467 amount 01   1610
# Current delta = 0.007839059246970124  amount 1/2 7331 amount 01   1705
# Current delta = 0.007839059246970124  amount 1/2 7237 amount 01   1773
# Current delta = 0.007839059246970124  amount 1/2 7186 amount 01   1806
# Current delta = 0.007839059246970124  amount 1/2 7156 amount 01   1826
# Current delta = 0.003919529623485062  amount 1/2 5887 amount 01   2866
# Current delta = 0.003919529623485062  amount 1/2 5531 amount 01   3200
# Current delta = 0.003919529623485062  amount 1/2 5403 amount 01   3289
# Current delta = 0.001959764811742531  amount 1/2 3930 amount 01   4649
# Current delta = 0.001959764811742531  amount 1/2 3680 amount 01   4860
# Current delta = 0.0009798824058712655  amount 1/2 2087 amount 01   6408
# Current delta = 0.0009798824058712655  amount 1/2 1941 amount 01   6589
# Current delta = 0.0004899412029356327  amount 1/2 1008 amount 01   8098
# Current delta = 0.00024497060146781637  amount 1/2 430 amount 01   9098
# Current delta = 0.00012248530073390818  amount 1/2 217 amount 01   9577
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   460.44097685813904
# Begin sim 49
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9992 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9991 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9988 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9981 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9865 amount 01   23
# Current delta = 0.015678118493940248  amount 1/2 9702 amount 01   142
# Current delta = 0.015678118493940248  amount 1/2 9490 amount 01   288
# Current delta = 0.015678118493940248  amount 1/2 9244 amount 01   397
# Current delta = 0.015678118493940248  amount 1/2 9085 amount 01   497
# Current delta = 0.015678118493940248  amount 1/2 8979 amount 01   563
# Current delta = 0.015678118493940248  amount 1/2 8903 amount 01   600
# Current delta = 0.007839059246970124  amount 1/2 8029 amount 01   1156
# Current delta = 0.007839059246970124  amount 1/2 7589 amount 01   1518
# Current delta = 0.007839059246970124  amount 1/2 7337 amount 01   1705
# Current delta = 0.007839059246970124  amount 1/2 7222 amount 01   1777
# Current delta = 0.003919529623485062  amount 1/2 5905 amount 01   2847
# Current delta = 0.003919529623485062  amount 1/2 5531 amount 01   3193
# Current delta = 0.003919529623485062  amount 1/2 5405 amount 01   3284
# Current delta = 0.001959764811742531  amount 1/2 3921 amount 01   4647
# Current delta = 0.001959764811742531  amount 1/2 3678 amount 01   4858
# Current delta = 0.0009798824058712655  amount 1/2 2089 amount 01   6403
# Current delta = 0.0009798824058712655  amount 1/2 1934 amount 01   6588
# Current delta = 0.0004899412029356327  amount 1/2 1009 amount 01   8099
# Current delta = 0.00024497060146781637  amount 1/2 431 amount 01   9097
# Current delta = 0.00012248530073390818  amount 1/2 218 amount 01   9576
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   478.1148216724396
# Begin sim 50
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9992 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9991 amount 01   8
# Current delta = 0.031356236987880495  amount 1/2 9989 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9987 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9982 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9872 amount 01   21
# Current delta = 0.015678118493940248  amount 1/2 9710 amount 01   138
# Current delta = 0.015678118493940248  amount 1/2 9503 amount 01   284
# Current delta = 0.015678118493940248  amount 1/2 9257 amount 01   393
# Current delta = 0.015678118493940248  amount 1/2 9092 amount 01   488
# Current delta = 0.015678118493940248  amount 1/2 8981 amount 01   564
# Current delta = 0.015678118493940248  amount 1/2 8907 amount 01   599
# Current delta = 0.015678118493940248  amount 1/2 8873 amount 01   620
# Current delta = 0.007839059246970124  amount 1/2 7993 amount 01   1180
# Current delta = 0.007839059246970124  amount 1/2 7565 amount 01   1540
# Current delta = 0.007839059246970124  amount 1/2 7327 amount 01   1713
# Current delta = 0.007839059246970124  amount 1/2 7213 amount 01   1781
# Current delta = 0.003919529623485062  amount 1/2 5905 amount 01   2848
# Current delta = 0.003919529623485062  amount 1/2 5534 amount 01   3192
# Current delta = 0.003919529623485062  amount 1/2 5406 amount 01   3286
# Current delta = 0.001959764811742531  amount 1/2 3926 amount 01   4645
# Current delta = 0.001959764811742531  amount 1/2 3678 amount 01   4859
# Current delta = 0.0009798824058712655  amount 1/2 2091 amount 01   6402
# Current delta = 0.0009798824058712655  amount 1/2 1934 amount 01   6587
# Current delta = 0.0004899412029356327  amount 1/2 1009 amount 01   8099
# Current delta = 0.00024497060146781637  amount 1/2 430 amount 01   9098
# Current delta = 0.00012248530073390818  amount 1/2 218 amount 01   9577
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   493.7774119377136
# Begin sim 51
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9997 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9992 amount 01   7
# Current delta = 0.031356236987880495  amount 1/2 9989 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9987 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9980 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9861 amount 01   26
# Current delta = 0.015678118493940248  amount 1/2 9692 amount 01   145
# Current delta = 0.015678118493940248  amount 1/2 9471 amount 01   292
# Current delta = 0.015678118493940248  amount 1/2 9231 amount 01   404
# Current delta = 0.015678118493940248  amount 1/2 9077 amount 01   501
# Current delta = 0.015678118493940248  amount 1/2 8975 amount 01   565
# Current delta = 0.015678118493940248  amount 1/2 8901 amount 01   601
# Current delta = 0.007839059246970124  amount 1/2 8024 amount 01   1156
# Current delta = 0.007839059246970124  amount 1/2 7588 amount 01   1521
# Current delta = 0.007839059246970124  amount 1/2 7337 amount 01   1705
# Current delta = 0.007839059246970124  amount 1/2 7222 amount 01   1777
# Current delta = 0.003919529623485062  amount 1/2 5906 amount 01   2847
# Current delta = 0.003919529623485062  amount 1/2 5531 amount 01   3194
# Current delta = 0.003919529623485062  amount 1/2 5404 amount 01   3285
# Current delta = 0.001959764811742531  amount 1/2 3921 amount 01   4647
# Current delta = 0.001959764811742531  amount 1/2 3678 amount 01   4858
# Current delta = 0.0009798824058712655  amount 1/2 2089 amount 01   6404
# Current delta = 0.0009798824058712655  amount 1/2 1934 amount 01   6588
# Current delta = 0.0004899412029356327  amount 1/2 1009 amount 01   8098
# Current delta = 0.00024497060146781637  amount 1/2 431 amount 01   9097
# Current delta = 0.00012248530073390818  amount 1/2 218 amount 01   9576
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   492.28248286247253
# Begin sim 52
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9992 amount 01   2
# Current delta = 0.031356236987880495  amount 1/2 9990 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9987 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9968 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9843 amount 01   36
# Current delta = 0.015678118493940248  amount 1/2 9670 amount 01   176
# Current delta = 0.015678118493940248  amount 1/2 9426 amount 01   307
# Current delta = 0.015678118493940248  amount 1/2 9199 amount 01   423
# Current delta = 0.015678118493940248  amount 1/2 9058 amount 01   515
# Current delta = 0.015678118493940248  amount 1/2 8962 amount 01   570
# Current delta = 0.015678118493940248  amount 1/2 8894 amount 01   603
# Current delta = 0.007839059246970124  amount 1/2 8017 amount 01   1163
# Current delta = 0.007839059246970124  amount 1/2 7579 amount 01   1523
# Current delta = 0.007839059246970124  amount 1/2 7332 amount 01   1709
# Current delta = 0.007839059246970124  amount 1/2 7216 amount 01   1776
# Current delta = 0.003919529623485062  amount 1/2 5907 amount 01   2846
# Current delta = 0.003919529623485062  amount 1/2 5531 amount 01   3192
# Current delta = 0.003919529623485062  amount 1/2 5405 amount 01   3285
# Current delta = 0.001959764811742531  amount 1/2 3922 amount 01   4647
# Current delta = 0.001959764811742531  amount 1/2 3677 amount 01   4859
# Current delta = 0.0009798824058712655  amount 1/2 2089 amount 01   6404
# Current delta = 0.0009798824058712655  amount 1/2 1935 amount 01   6588
# Current delta = 0.0004899412029356327  amount 1/2 1009 amount 01   8098
# Current delta = 0.00024497060146781637  amount 1/2 430 amount 01   9097
# Current delta = 0.00012248530073390818  amount 1/2 218 amount 01   9577
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   488.25493693351746
# Begin sim 53
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 10000 amount 01   0
# Current delta = 0.015678118493940248  amount 1/2 9989 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9988 amount 01   11
# Current delta = 0.007839059246970124  amount 1/2 9817 amount 01   43
# Current delta = 0.007839059246970124  amount 1/2 9453 amount 01   327
# Current delta = 0.007839059246970124  amount 1/2 8654 amount 01   742
# Current delta = 0.007839059246970124  amount 1/2 8035 amount 01   1157
# Current delta = 0.007839059246970124  amount 1/2 7683 amount 01   1454
# Current delta = 0.007839059246970124  amount 1/2 7434 amount 01   1626
# Current delta = 0.007839059246970124  amount 1/2 7317 amount 01   1722
# Current delta = 0.007839059246970124  amount 1/2 7225 amount 01   1779
# Current delta = 0.007839059246970124  amount 1/2 7179 amount 01   1809
# Current delta = 0.015678118493940248  amount 1/2 9424 amount 01   311
# Current delta = 0.015678118493940248  amount 1/2 9197 amount 01   424
# Current delta = 0.015678118493940248  amount 1/2 9057 amount 01   517
# Current delta = 0.015678118493940248  amount 1/2 8959 amount 01   573
# Current delta = 0.015678118493940248  amount 1/2 8891 amount 01   603
# Current delta = 0.007839059246970124  amount 1/2 8015 amount 01   1163
# Current delta = 0.007839059246970124  amount 1/2 7578 amount 01   1524
# Current delta = 0.007839059246970124  amount 1/2 7332 amount 01   1710
# Current delta = 0.007839059246970124  amount 1/2 7215 amount 01   1775
# Current delta = 0.003919529623485062  amount 1/2 5908 amount 01   2846
# Current delta = 0.003919529623485062  amount 1/2 5532 amount 01   3192
# Current delta = 0.003919529623485062  amount 1/2 5406 amount 01   3285
# Current delta = 0.001959764811742531  amount 1/2 3921 amount 01   4647
# Current delta = 0.001959764811742531  amount 1/2 3677 amount 01   4859
# Current delta = 0.0009798824058712655  amount 1/2 2089 amount 01   6404
# Current delta = 0.0009798824058712655  amount 1/2 1935 amount 01   6588
# Current delta = 0.0004899412029356327  amount 1/2 1009 amount 01   8098
# Current delta = 0.00024497060146781637  amount 1/2 430 amount 01   9097
# Current delta = 0.00012248530073390818  amount 1/2 218 amount 01   9577
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   489.7029392719269
# Begin sim 70
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 9992 amount 01   3
# Current delta = 0.031356236987880495  amount 1/2 9989 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9987 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9981 amount 01   11
# Current delta = 0.015678118493940248  amount 1/2 9863 amount 01   23
# Current delta = 0.015678118493940248  amount 1/2 9698 amount 01   143
# Current delta = 0.015678118493940248  amount 1/2 9481 amount 01   288
# Current delta = 0.015678118493940248  amount 1/2 9236 amount 01   400
# Current delta = 0.015678118493940248  amount 1/2 9083 amount 01   500
# Current delta = 0.015678118493940248  amount 1/2 8978 amount 01   564
# Current delta = 0.015678118493940248  amount 1/2 8902 amount 01   601
# Current delta = 0.007839059246970124  amount 1/2 8024 amount 01   1156
# Current delta = 0.007839059246970124  amount 1/2 7588 amount 01   1519
# Current delta = 0.007839059246970124  amount 1/2 7337 amount 01   1705
# Current delta = 0.007839059246970124  amount 1/2 7222 amount 01   1777
# Current delta = 0.003919529623485062  amount 1/2 5906 amount 01   2847
# Current delta = 0.003919529623485062  amount 1/2 5531 amount 01   3194
# Current delta = 0.003919529623485062  amount 1/2 5404 amount 01   3285
# Current delta = 0.001959764811742531  amount 1/2 3921 amount 01   4647
# Current delta = 0.001959764811742531  amount 1/2 3678 amount 01   4858
# Current delta = 0.0009798824058712655  amount 1/2 2089 amount 01   6404
# Current delta = 0.0009798824058712655  amount 1/2 1934 amount 01   6588
# Current delta = 0.0004899412029356327  amount 1/2 1009 amount 01   8098
# Current delta = 0.00024497060146781637  amount 1/2 431 amount 01   9097
# Current delta = 0.00012248530073390818  amount 1/2 218 amount 01   9576
# Current delta = 0.0  amount 1/2 0 amount 01   10000
# sim time   474.487717628479
# Begin sim 71
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.06271247397576099  amount 1/2 10000 amount 01   0
# Current delta = 0.031356236987880495  amount 1/2 10000 amount 01   0
# Current delta = 0.015678118493940248  amount 1/2 9993 amount 01   0
# Current delta = 0.015678118493940248  amount 1/2 9989 amount 01   8
# Current delta = 0.015678118493940248  amount 1/2 9988 amount 01   11
# Current delta = 0.007839059246970124  amount 1/2 9937 amount 01   19
# Current delta = 0.007839059246970124  amount 1/2 9649 amount 01   189
# Current delta = 0.007839059246970124  amount 1/2 9152 amount 01   474
# Current delta = 0.007839059246970124  amount 1/2 8369 amount 01   901
# Current delta = 0.007839059246970124  amount 1/2 7918 amount 01   1255
# Current delta = 0.007839059246970124  amount 1/2 7629 amount 01   1506
# Current delta = 0.007839059246970124  amount 1/2 7412 amount 01   1649
# Current delta = 0.007839059246970124  amount 1/2 7312 amount 01   1730
# Current delta = 0.007839059246970124  amount 1/2 7227 amount 01   1788
# Current delta = 0.007839059246970124  amount 1/2 7178 amount 01   1814

# %% [markdown]
# # Visualization

# %%
feat_partitions = FP_K2.get_feature_partitions()

# %%
emb_all = TSNE(n_components=3, perplexity=40, random_state=42).fit_transform(x_new_SVD[0]*x_new_SVD[1])
emb_ours = [ TSNE(n_components=3, perplexity=40, random_state=42).fit_transform((x_new_SVD[0]*x_new_SVD[1])@x_new_SVD[2][:, feat_partitions[s]]) for s in range(K)]

# %%
colors1= ['blue','grey','brown']
colors2= ['orange','purple','green']
alpha=0.1
s=3
f,ax= plt.subplots(2,3,figsize=(14,10),subplot_kw={'projection':'3d'})
for i,l in enumerate(['LD','UD','DC']):
    alpha=[0.5,0.3,0.9][i]*0.8

    inds= np.where(np.array(cell_types)==l)[0]
    ax[0,0].scatter(emb_all[inds,0], emb_all[inds,1], emb_all[inds,2],label=l,alpha=alpha,s=s,c=colors1[i])
    ax[0,1].scatter(emb_ours[0][inds,0], emb_ours[0][inds,1], emb_ours[0][inds,2],label=l,alpha=alpha,s=s,c=colors1[i])
    ax[0,2].scatter(emb_ours[1][inds,0], emb_ours[1][inds,1], emb_ours[1][inds,2],label=l,alpha=alpha,s=s,c=colors1[i])


for i,l in enumerate(['G1','S','G2M']):
    alpha=[0.5,0.5,0.3][i]*0.8

    inds= np.where(np.array(phase_types)==l)[0]
    ax[1,0].scatter(emb_all[inds,0], emb_all[inds,1], emb_all[inds,2],label=l,alpha=alpha,s=s,c=colors2[i])
    ax[1,1].scatter(emb_ours[0][inds,0], emb_ours[0][inds,1], emb_ours[0][inds,2],label=l,alpha=alpha,s=s,c=colors2[i])
    ax[1,2].scatter(emb_ours[1][inds,0], emb_ours[1][inds,1], emb_ours[1][inds,2],label=l,alpha=alpha,s=s,c=colors2[i])
    
l1= ax[0,2].legend(markerscale=8,loc='upper left', bbox_to_anchor=(1.05, 1),fontsize=20,labelspacing=2.5)
l2= ax[1,2].legend(markerscale=8,loc='upper left', bbox_to_anchor=(1.05, 1),fontsize=20,labelspacing=2.5)

for lh in l1.legend_handles: 
    lh.set_alpha(1)
for lh in l2.legend_handles: 
    lh.set_alpha(1)

for a in ax.flatten():
    a.set_xticks([])
    a.set_yticks([])
    a.set_zticks([])


ax[0,0].set_title('All Genes',fontsize=25)
ax[0,1].set_title('tSNE Embedding based on\nPartition 1 Genes',fontsize=25)
ax[0,2].set_title('Partition 2 Genes',fontsize=25)

f.patch.set_facecolor('white')

for a in ax.flatten():
    a.set_facecolor('white')

for i in range(2):
    ax[i,0].view_init(30,-145)
    ax[i,1].view_init(-15,50+185)
    ax[i,2].view_init(30,110)

# %% [markdown]
# # Genes Analysis

# %%
opt_params= FP_K2.get_optimal_parameters()
W= opt_params['W']

# %%
wanted_genes= np.array([np.where(gene_names =='Foxd1' ),\
                       np.where(gene_names =='Sox2' ),\
                       np.where(gene_names =='Mki67' ),\
                       np.where(gene_names =='Ccna2' ),\
                       np.where(gene_names =='Ptch1' ),\
                       np.where(gene_names =='Lef1' )]).flatten()
wanted_genes
# Out:
# array([7441, 1473, 4374, 1481, 7331, 1899])

# %%
for i in wanted_genes:
    for j in range(K):
        if (i in feat_partitions[j]):
            print(j)
# Out:
# 1
# 1
# 0
# 0
# 1
# 1

# %%
from scipy.spatial.distance import pdist,squareform
def LaplacianScore(W,x, isZscored=True):
    if not isZscored:
        return np.mean(np.sum(W+W.T,axis=1,keepdims=True)*x**2,axis=0) -2* np.mean((W@x)*x,axis=0)   
    
    newX= (x-np.mean(x,axis=0,keepdims=True))/(1e-10+ np.std(x,axis=0,keepdims=True))
    
    
    res= np.mean(np.sum(W+W.T,axis=1,keepdims=True)*newX**2,axis=0) -2* np.mean((W@newX)*newX,axis=0)
    res[np.where(np.std(x,axis=0)<1e-10)[0]]=1e10
    return res


    #return np.mean(np.sum(W+W.T,axis=1,keepdims=True)*x**2,axis=0) -2* np.mean((W@x)*x,axis=0)

# %%
cur_gene_indes =[]
score_genes = []
for i in range(K):
    cur_scores= LaplacianScore(W[i], (x_new_SVD[0]*x_new_SVD[1])@x_new_SVD[2][:, feat_partitions[i]], isZscored=True)
    cur_genes=  feat_partitions[i][np.argsort(cur_scores)]
    cur_scores= np.sort(cur_scores)

    cur_gene_indes.append( cur_genes+0)
    score_genes.append( cur_scores+0)

# %%
for i in range(K):
    print(np.array(gene_names)[cur_gene_indes[i][:40]])
# Out:
# ['Dbf4' 'Nuf2' 'Kif11' 'Prc1' 'Melk' 'Sgo2a' 'Knl1' 'Nusap1' 'Bub1'
#  'Ndc80' 'Kif4' 'Sgo1' 'Kif20b' 'Incenp' 'Kif22' 'Ube2c' 'Kif15' 'Ckap2l'
#  'Spc25' 'Top2a' 'Ccna2' 'Ncapg' 'Mis18bp1' 'Shcbp1' 'Anln' 'Cenpf' 'Mxd3'
#  'Spdl1' 'Mki67' 'Tpx2' 'Ska1' 'Ttk' 'Cenpe' 'Pbk' 'Aurkb' 'Ccnb1'
#  'Racgap1' 'Hmmr' 'Cdca8' 'Mad2l1']
# ['Nrk' 'Itm2a' 'Agtr2' 'Plagl1' 'Akap12' 'Loxl1' 'Rbp1' 'Lix1' 'Fibin'
#  'Rtl3' 'Dpt' 'Cdkn1c' 'Col7a1' 'Sfrp2' 'Tshz2' 'Tmeff2' 'Crabp1' 'Pdpn'
#  'Angptl1' 'Creb5' 'Ptgis' 'Postn' 'H19' 'Igf2' 'Lef1' 'Man2a1' 'Ogn'
#  'Igfbp4' 'Sema3c' 'Cavin2' 'Zfhx4' 'Abi3bp' 'Bcl11b' 'Fgf7' 'Ptn' 'Klf4'
#  'Lox' 'Lhfpl2' 'Kcnj8' 'Runx3']

# %% [markdown]
# ## Compare with Seurat Cell- Cycle genes

# %%
# Seurat's cell-cycle genes were extracted from R using the following R code:
# 
# library(Seurat)
# library(gprofiler2)
#
# genes_s = gorth(cc.genes.updated.2019$s.genes, source_organism = "hsapiens", target_organism = "mmusculus")$ortholog_name 
# genes_g2m = gorth(cc.genes.updated.2019$g2m.genes, source_organism = "hsapiens", target_organism = "mmusculus")$ortholog_name 
# genes_c = c(genes_s,genes_g2m)
# cat(paste(shQuote(genes_c), collapse = ","))

CC_genes= ['Mcm5','Pcna','Tyms','Fen1','Mcm7','Mcm4','Rrm1','Ung','Gins2','Mcm6','Cdca7','Dtl','Prim1','Uhrf1','Cenpu','Hells','Rfc2','Polr1b','Nasp','Rad51ap1','Gmnn','Wdr76','Slbp','Ccne2','Ubr7','Msh2','Rad51','Rrm2','Cdc45','Cdc6','Exo1','Tipin','Dscc1','Blm','Casp8ap2','Usp1','Clspn','Pola1','Chaf1b','Mrpl36','E2f8','Hmgb2','Cdk1','Nusap1','Ube2c','Birc5','Tpx2','Top2a','Ndc80','Cks2','Nuf2','Cks1b','Mki67','Tmpo','Cenpf','Tacc3','Pimreg','Smc4','Ccnb2','Ckap2l','Ckap2','Aurkb','Bub1','Kif11','Anp32e','Tubb4b','Gtse1','Kif20b','Hjurp','Cdca3','Jpt1','Cdc20','Ttk','Cdc25c','Kif2c','Rangap1','Ncapd2','Dlgap5','Cdca2','Cdca8','Ect2','Kif23','Hmmr','Aurka','Psrc1','Anln','Lbr','Ckap5','Cenpe','Ctcf','Nek2','G2e3','Gas2l3','Cbx5','Cenpa']

print('Number of Seurat CC phase Genes :'+str(len(CC_genes)))
print('Number of Seurat CC phase Genes after the preprocessing :'+str(len([a for a in CC_genes if a in gene_names])))
print('Number of Seurat CC phase Genes after the preprocessing within partition 1 :'+str(len([a for a in CC_genes if a in gene_names[feat_partitions[0]]])))
print()
# Out:
# Number of Seurat CC phase Genes :95
# Number of Seurat CC phase Genes after the preprocessing :93
# Number of Seurat CC phase Genes after the preprocessing within partition 1 :93
